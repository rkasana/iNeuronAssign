# %% [markdown]
# https://towardsdatascience.com/ensemble-methods-bagging-boosting-and-stacking-c9214a10a205

# %% [markdown]
# ## Ensemble and Random Forest

# %% [markdown]
# 1)	What do you understand by Ensemble technique?

# %% [markdown]
# Ensemble methods are meta-algorithms that combine several machine learning techniques(often called "weak learners") into one predictive model in order to decrease variance(bagging), bias(boosting), or improve predictions(stacking). The main hypothesis behind ensemble techniques is that when weak models are correctly combined, more accurate and/or robust models are obtaines.
#
# Ensemble methods can be divided into two groups:
# 1.Sequential ensemble methods where the base learners are generated sequentially (eg. AdaBoost).
# the basic motivation of sequential methods is to **exploit the dependence between the base learners.** The overall performance can be boosted by weighing previously mislabeled examples with higher weight.
#
# 2. parallel ensemble methods where the base learners are generated in parallel(e.g. Random Forest)
# The basic motivation of parallel methods is to **exploit independence between the base learners** since the error can be reduced dramatically by averaging.
#
# Most ensemble methods use a single base learning algorithm to produce homegenous base learners i.e. learners of the same type, leading to homogenous ensembles.
# There are also some methods that use heterogenous learners,i.e. learners of diffrent types. In order  for ensemble methods to be more accurate than any of its indiviual members, the base learners have to be more accurate and as diverse as possible.

# %% [markdown]
# 2)	Explain the idea behind ensemble techniques.

# %% [markdown]
# In machine learning, no matter if we are facing a classification or a regression problem, the choice of the model is extremely important to have any chance to obtain good results. This choice can depend on many variables of the problem: quantity of data, dimensionality of the space , distributed hypothesis.
#
# A low bias and a low variance, although thet most often vary in opposite directions, are the two most fundamentals features expected for a model. Indeed, to be able to "solve" a problem, we want our model to have enough degrees of reedom to resolve the underlying complexity of the data we are working with, but we also want it to have not much degree of freedom to avoid high variance and be more robust. This is the well known bias-variance tradeoff.
# ![Screenshot%20from%202020-05-04%2015-21-52.png](attachment:Screenshot%20from%202020-05-04%2015-21-52.png)
#
# In ensemble learning theory, we call weak learners (or base models) models that can be used as building blocks for designing more complex models by combining several of them. Most of the time, these basics models perform not so well by themselves either because they have a high bias (low degree of freedom models, for example) or because they have too much variance to be robust (high degree of freedom models, for example). Then the idea of ensemble methods is to try reducing bias and/or variance of such weak learners by combining several of them together in order to create a **strong learner** (or ensemble model) that achieves better performances.

# %% [markdown]
# 3)	What is Bootstrapping? How is sampling done in bootstrapping?

# %% [markdown]
# In statstics, bootstraping refers to a resample method that consists of repeatedly drawn, with replacement, samples from data to form other smaller datasets, called bootstraping samples. It's as if the bootstraping method is making a bunch of situations to our original dataset so in some cases we can generalize the mean and the standard deviation.
#
# For ex. Lets say we have a set of observations:[2,3,32,8,16]. If we want each bootstrap sample containing n obseravation, the following are valid samples:
# n=3:[32,4,4],[8,16,2].[2,2,2]
# n=4:[2,32,4,16],[2,4,2,8],[8,32,4,2]
# Since we drawn data with replacement, the observation can appear more than one time in a single sample.

# %% [markdown]
# 4)	What is bagging?

# %% [markdown]
# Bagging stands for bootstrap aggregation and it is a ensemble method in which multiple estimates are averaged together to reduce the variance of an estimate. For example, we can train M diffrent trees on diffrent subsets of data (chosen randomly with replacement) and compute the ensemble:
# ![Screenshot%20from%202020-05-04%2013-59-19.png](attachment:Screenshot%20from%202020-05-04%2013-59-19.png)
#
# Bagging uses bootstrap sampling to obtain the data subsets for training the base learners. For aggregating the outputs of base learners, bagging uses voting for classification and averaging for regression.

# %% [markdown]
# 5)	How prediction is made in Bagging?

# %% [markdown]
# 6)	How Ensemble technique solves the high variance issue with Decision trees?

# %% [markdown]
# 7)	What is pasting? How is it different from bagging?

# %% [markdown]
# 8)	What is Out-Of-Bag evaluation?

# %% [markdown]
# If we are using bagging, there is a chance that a sample would bever be selected, while another may be selected multiple time. The probablity of not selecting a specific sample is (1-1/n), where n is the number of samples. Therefore, the probablity of not picking n samples in n draws is (1-1/n)^n. When the value of n is big, we can approximate this probablity to 1/e, which is approximately 0.3678. This means that we could use it to test our model. This is called out-of-bag scoring, or OOB scoring.

# %% [markdown]
# 9)	How does a Random Forest model works?
# https://towardsdatascience.com/an-implementation-and-explanation-of-the-random-forest-in-python-77bf308a9b76

# %% [markdown]
# As the name suggest, a random forest is an ensemble of decision trees that can be used for classification or regression. Each tree in the forest outputs a prediction and the most voted becomes the output of the model. This is helpful to make the model with more accuracy and stable, preventing overfitting.
# Random forest model uses two key concepts that gives it the name random:
# 1. Random sampling of training data points when building trees
# 2. random subsets of features considered whhen splitting nodes
#
# Random samppling of training observation:
# When training, each tree in a random forest learns from a random sample of the data points. The samples are drawn with replacement, know as bootstraping, which means that some samples wil be used multiple times in a single tree. The idea is that by training each tree on diffrent samples, although each tree might have high variance with respect to a particular set of the traing data, overall the entire forest will have ower variance but not at the cost of increasing the bias.
#
# At test time, predictions are made by averaging the predictions of each decision tree. This procedure of training each indiviual learner on diffrent bootstrapped

# %% [markdown]
# 10)	What is the difference between Bagging and Random forest? Why do we use Random forest more commonly than Bagging?

# %% [markdown]
# 11)	What is feature sampling?

# %% [markdown]
# 12)	How prediction is made in Random Forest?

# %% [markdown]
# 13)	When should we not use Random forest model?

# %% [markdown]
# 14)	What is Stacking?

# %% [markdown]
# Stacking is an ensemble learning technique that combines multiple classification or regression models via a meta classifier or a meta-regressor. The base level models are trained on a complete traing set, then the meta-model is trained on the outputs of the base level models as features. The base level often consists of diffrent learning algorithms and therefore stacking ensembles are often heterogeneous.

# %% [markdown]
# 15)	Explain the working behind Stacking.

# %% [markdown]
# The idea of stacking is to learn several diffrent weak learners and combine them by training a meta-model to output predictions based on the multiple predictions returned by thses weak models. So, two things are defined to build a stacking model: the L learners to be fitted and the meta-model that combines them.
# For ex: For a classification problem, KNN classifier, a logistic regression and a SVM can be chosen as weak learners. Also, a neural network is chosen as meta-model. The neural network will take the outputs of three weak learners as input and will learn to return final predictions based on it.
#
# To fit a stacking ensemble composed of L weak learners, following steps are followed:
# * split the training data in two folds
# * choose L weak learners and fit them to data of the first fold
# * for each of the L weak learners, make predictions for observations in the second fold.
# * fit the meta-model on the second fold, using predictions made by the weak learners as input.
# ![Screenshot%20from%202020-05-04%2015-08-30.png](attachment:Screenshot%20from%202020-05-04%2015-08-30.png)
